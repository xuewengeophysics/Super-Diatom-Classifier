# %%
import tensorflow as tf

# %%
for example in tf.compat.v1.io.tf_record_iterator("/home/GTL/pfauregi/Training/setup02/data/train_dataset.record"):
    print(tf.train.Example.FromString(example))
    time.sleep(1)
# Out:
# features {
#   feature {
#     key: "image/encoded"
#     value {
#       bytes_list {
# ...
