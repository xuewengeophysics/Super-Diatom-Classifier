# %%
#si les diatomees sont en vrac dans region
import xlrd
import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt
from collections import OrderedDict
from openpyxl import Workbook

# %run ./data_info.ipynb



#A MODIFIER
#------------------------------------chemin du dossier a analyser
#DATASET_PATH = "../../../nvme-storage/RA/tmp"
DATASET_PATH =  "../../../nvme-storage/BRG_V1/BRG"

#------------------------------------chemin du tableau a analyser
BOARD_PATH = "/mnt/nvme-storage/souhila/Info_BR_M.xlsx"




#A LANCER TEL QUEL
#------------------------------------lecture du tableau à remplir
classeur = pd.read_excel(BOARD_PATH)
#classeur2 = pd.read_excel("/mnt/nvme-storage/souhila/Info_BR_M.xlsx" ,index_col= [0])

#------------------------------------application du code
images = [f for f in listdir(DATASET_PATH) if isfile(join(DATASET_PATH, f))]
#classeur = classeur.drop(['Unnamed: 5', 'Unnamed: 6' ,'Unnamed: 7','Unnamed: 8' ,'Unnamed: 9' ,'Unnamed: 10' ,'Unnamed: 11' ,'Unnamed: 12' ,'Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17'], axis=1) 
#classeur2 = classeur2.drop(['Unnamed: 5', 'Unnamed: 6' ,'Unnamed: 7','Unnamed: 8' ,'Unnamed: 9' ,'Unnamed: 10' ,'Unnamed: 11' ,'Unnamed: 12' ,'Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17'], axis=1) 

region, compte =count_taxon(images)
dico_RA, dico, region = index_info_data(classeur, region, compte)
Z2 = fill_info_data(dico_RA,classeur2,dico,region)
writer = pd.ExcelWriter(BOARD_PATH)
Z2.to_excel(writer, "Sheet1",index = True)
writer.save()

# %%
#si les diatomees sont rangee par classe dans region
import xlrd
import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt
from collections import OrderedDict
from openpyxl import Workbook
import os.path
from os import scandir
import os 
# %run ./data_info.ipynb



#A MODIFIER
#DATASET_PATH =  "../../../nvme-storage/BRG_V1/BRG"
#ROOT = "../../../nvme-storage/BRG_V1/BRG"
#region = "BRG"


DATASET_PATH =  "../../../nvme-storage/IDF_V3/IDF"
ROOT = "../../../nvme-storage/IDF_V3/IDF"
region = "IDF"


#------------------------------------chemin du tableau a analyser
BOARD_PATH = "/mnt/nvme-storage/souhila/Info_BR_M.xlsx"




#A LANCER TEL QUEL
#------------------------------------lecture du tableau à remplir
#classeur = pd.read_excel(BOARD_PATH)
#classeur2 = pd.read_excel("/mnt/nvme-storage/souhila/Info_BR_M.xlsx" ,index_col= [0])

#------------------------------------application du code
#images = [f for f in listdir(DATASET_PATH) if isfile(join(DATASET_PATH, f))]
#classeur = classeur.drop(['Unnamed: 5', 'Unnamed: 6' ,'Unnamed: 7','Unnamed: 8' ,'Unnamed: 9' ,'Unnamed: 10' ,'Unnamed: 11' ,'Unnamed: 12' ,'Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17'], axis=1) 
#classeur2 = classeur2.drop(['Unnamed: 5', 'Unnamed: 6' ,'Unnamed: 7','Unnamed: 8' ,'Unnamed: 9' ,'Unnamed: 10' ,'Unnamed: 11' ,'Unnamed: 12' ,'Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17'], axis=1) 

classeur, info_data = info_data_classe(ROOT,region,BOARD_PATH)
classeur = classeur.fillna(0)
classeur = classeur.drop(['Unnamed: 0'],axis = 1)
writer = pd.ExcelWriter(BOARD_PATH)
classeur.to_excel(writer, "Sheet1",index = True)
writer.save()
