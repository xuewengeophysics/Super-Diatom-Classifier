# %% [markdown]
# # Testing

# %% [markdown]
# ### Imports

# %%
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile
import io
import cv2

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image
from IPython.display import display
import pathlib

# %run ./utils.ipynb

# %%
from object_detection.utils import ops as utils_ops
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as vis_util

# %%
# patch tf1 into `utils.ops`
utils_ops.tf = tf.compat.v1

# Patch the location of gfile
tf.gfile = tf.io.gfile

# %% [markdown]
# # Model preparation

# %% [markdown]
# ## Loader

# %%
model = tf.saved_model.load("/mnt/nvme-storage/pfauregi/training/setup01/models/model/export/saved_model")
model = model.signatures['serving_default']
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore

# %% [markdown]
# ## Loading label map

# %%
# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = '/mnt/nvme-storage/pfauregi/training/setup02/data/binary_label_map.pbtxt'
category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS, use_display_name=True)

# %% [markdown]
# # Detection

# %%
print(model.inputs)
print(model.output_dtypes)
print(model.output_shapes)
# Out:
# [<tf.Tensor 'image_tensor:0' shape=(None, None, None, 3) dtype=uint8>]
# {'detection_features': tf.float32, 'detection_scores': tf.float32, 'raw_detection_scores': tf.float32, 'detection_multiclass_scores': tf.float32, 'detection_classes': tf.float32, 'raw_detection_boxes': tf.float32, 'detection_boxes': tf.float32, 'num_detections': tf.float32}
# {'detection_features': TensorShape([None, None, None, None, None]), 'detection_scores': TensorShape([None, 300]), 'raw_detection_scores': TensorShape([None, 300, 2]), 'detection_multiclass_scores': TensorShape([None, 300, 2]), 'detection_classes': TensorShape([None, 300]), 'raw_detection_boxes': TensorShape([None, 300, 4]), 'detection_boxes': TensorShape([None, 300, 4]), 'num_detections': TensorShape([None])}

# %%
sample = load_image("/mnt/nvme-storage/pfauregi/training/sample.png")
result = run_inference_for_single_image(model,sample)

# %%
show_inference(result, sample, 30)
# Out:
# <PIL.Image.Image image mode=RGB size=2048x1536 at 0x7FF6A47F8CF8>

# %%
cv2.imwrite("yey.png", sample)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5f7b23d94e56> in <module>
# ----> 1 cv2.imwrite("yey.png", image)
#
# NameError: name 'image' is not defined
